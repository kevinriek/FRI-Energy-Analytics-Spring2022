# %%
import numpy as np                        # ndarrys for gridded data
import pandas as pd                       # DataFrames for tabular data
import os                                 # set working directory, run executables
import matplotlib.pyplot as plt           # for plotting
import copy                               # for deep copies
import warnings
import json
import properscoring as ps
import random

# %%
from gluonts.model.deepar import DeepAREstimator
from gluonts.mx.trainer import Trainer
from gluonts.dataset.util import to_pandas
from gluonts.evaluation import make_evaluation_predictions
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions
from gluonts.evaluation import Evaluator
from gluonts.dataset.field_names import FieldName

from sklearn.metrics import mean_squared_error as mse
from sklearn.preprocessing import MinMaxScaler
import scipy
import logging

# %%
#Display all of the rows in a dataframe
pd.set_option('display.max_rows', 10000)
warnings.filterwarnings("ignore")
sc = MinMaxScaler()
sens_analysis = False
pred_len = 60

# %%
filename = os.path.abspath('') + '\\Data\\Filtered\\FilteredProduction.xlsx'
file = open(filename, "rb")
prodDF = pd.read_excel(file, engine="openpyxl")

filename = os.path.abspath('') + '\\Data\\Filtered\\FilteredInjection.xlsx'
file = open(filename, "rb")
injectDF = pd.read_excel(file, engine="openpyxl")

filename = "LongestProductionWells.xlsx"
filename = os.path.abspath('') + "\\Data\\Use\\" + filename
file = open(filename, "rb")
testDF = pd.read_excel(file, engine='openpyxl')

# %%
###########    Injection by Unit     #########
p_units = prodDF.groupby(prodDF.Enhanced_Recovery_Unit)
i_units = injectDF.groupby(injectDF.Enhanced_Recovery_Unit)

# %%
def run_unit(name, p_unit, i_unit):
    #Group dataset by well
    well_groups = p_unit.groupby(p_unit.Well_Name)
    well_names = []
    wells = []
    
    prod_Data_Vol = 0
    inj_Data_Vol = 0
    
    for well, data in well_groups:
        well_names.append(well)
        if (len(data) > pred_len):
            wells.append(data)
            prod_Data_Vol += len(well)
    
    i_well_groups = i_unit.groupby(["Well_Name"])
    i_wells = []
    for i_well, data in i_well_groups:
        i_wells.append(data)
        inj_Data_Vol += len(i_well)
            
    train_list = []
    test_list = []
    for x in wells:
        length = x.Oil_bbls.size

        covar_train = []
        covar_test = []

        for i in i_wells:            #Injection: all wells
            i_well = i
            i_well = i_well.set_index(i_well.Date_Injection_Report)
            i_well = i_well[~i_well.index.duplicated()]
            
            i_well = i_well.reindex(x.Date_Production, fill_value=0)

            if (sens_analysis):
                #Set the test injection covariate values (to see effect)
                ratio = 1.0    #Proportion to set all test injection values to
                i_well.Vol_Fluid_Injected[int(length - pred_len):] = max(i_well.Vol_Fluid_Injected) * ratio

            #series = sc.fit_transform(i_well.Vol_Fluid_Injected.values.reshape(-1, 1))
            #series = series.reshape(1, -1)[0]
            #covar_train.append(series[:int(length - pred_len)])
            #covar_test.append(series)
            covar_train.append(i_well.Vol_Fluid_Injected[:int(length - pred_len)])
            covar_test.append(i_well.Vol_Fluid_Injected)
            
            
        #covar_train = sc.fit_transform(covar_train)
        #covar_test = sc.fit_transform(covar_test)

        prod_days = sc.fit_transform(x.Prod_Days.values.reshape(-1, 1))
        prod_days = prod_days.reshape(1, -1)[0]

        np.insert(covar_train, 0, prod_days[:int(length - pred_len)])
        np.insert(covar_test, 0, prod_days)

        train_list.append({
            'target': x.Oil_bbls[:int(length - pred_len)],
            'start': x.iloc[0].Date_Production,
            'feat_dynamic_real': covar_train
        })
        test_list.append({
            'target': x.Oil_bbls,
            'start': x.iloc[0].Date_Production,
            'feat_dynamic_real': covar_test
        })
    train_ds = ListDataset(train_list, freq="1M")
    test_ds = ListDataset(test_list, freq="1M")
    
    estimator = DeepAREstimator(freq="1M", prediction_length=pred_len, trainer=Trainer(epochs=25),
                                    #, learning_rate=.001,
                                    #num_batches_per_epoch=50), 
                                    use_feat_dynamic_real=True)  #Tuning without Injection!!!
                                    #num_cells=40, num_layers=1, dropout_rate=.6, batch_size=32,
                                    #context_length=30, cell_type='lstm')


    predictor = estimator.train(training_data=train_ds)
    forecast_it, ts_it = make_evaluation_predictions(
        dataset=test_ds,  # test dataset
        predictor=predictor,  # predictor
        num_samples=10,  # number of sample paths we want for evaluation          #Tune this value???
    )
    forecasts = list(forecast_it)
    tss = list(ts_it)
    
    evaluator = Evaluator(quantiles=[0.1, 0.5, 0.9])
    agg_metrics, item_metrics = evaluator(iter(tss), iter(forecasts), num_series=len(train_ds))
    
    crps_list = []
    for i in range(len(tss)):
        crps = ps.crps_ensemble(tss[i][(len(tss[i]) - pred_len):][0].values, np.transpose(forecasts[i].samples)).mean()
        crps_list.append(crps)

    item_metrics['Mean CRPS'] = crps_list
    item_metrics['RMSE'] = item_metrics['MSE']**(.5)
    agg_metrics['Mean CRPS'] = sum(crps_list)/len(crps_list)
    aggDF = pd.DataFrame([agg_metrics])
    
    ret_DF = {"Unit_Name":name, "Inj_Data_Vol":inj_Data_Vol, "Prod_Data_Vol":prod_Data_Vol,
              "agg_DF":aggDF, "forecasts":forecasts, "tss":tss, "agg_metrics":agg_metrics, "item_metrics":item_metrics}
    return ret_DF

# %%
results = []
for name, data in p_units:
    random.seed(42)
    if (name in ["Alum Creek Unit", "Buffalo Red River Unit", "Central Buffalo Red River Unit",
                "East Harding Springs Red River Unit", "North Buffalo Red River Unit",
                "Pete's Creek Red River Unit", "South Buffalo Red River Unit",
                "West Buffalo B Red River Unit", "West Buffalo Red River Unit"]):
        
        logging.warning(" Running Unit: " + name) 
        p_unit = p_units.get_group(name)
        i_unit = i_units.get_group(name)
        results.append(run_unit(name, p_unit, i_unit))
# Out:
# WARNING:root: Running Unit: Alum Creek Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.99it/s, epoch=1/25, avg_epoch_loss=7.94]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.74it/s, epoch=2/25, avg_epoch_loss=7.47]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.53it/s, epoch=3/25, avg_epoch_loss=7.35]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.69it/s, epoch=4/25, avg_epoch_loss=7.29]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.83it/s, epoch=5/25, avg_epoch_loss=7.26]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.62it/s, epoch=6/25, avg_epoch_loss=7.18]
# 100%|██████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.73it/s, epoch=7/25, avg_epoch_loss=7.2]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.73it/s, epoch=8/25, avg_epoch_loss=7.13]
# 100%|██████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.62it/s, epoch=9/25, avg_epoch_loss=7.1]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.74it/s, epoch=10/25, avg_epoch_loss=7.15]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.70it/s, epoch=11/25, avg_epoch_loss=7.09]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.71it/s, epoch=12/25, avg_epoch_loss=7.03]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.78it/s, epoch=13/25, avg_epoch_loss=7.05]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.76it/s, epoch=14/25, avg_epoch_loss=7.03]
# 100%|███████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.37it/s, epoch=15/25, avg_epoch_loss=7]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.69it/s, epoch=16/25, avg_epoch_loss=7.04]
# 100%|███████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.62it/s, epoch=17/25, avg_epoch_loss=7]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.42it/s, epoch=18/25, avg_epoch_loss=6.94]
# 100%|███████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.38it/s, epoch=19/25, avg_epoch_loss=7]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.45it/s, epoch=20/25, avg_epoch_loss=7.03]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.70it/s, epoch=21/25, avg_epoch_loss=6.95]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.70it/s, epoch=22/25, avg_epoch_loss=7.02]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.65it/s, epoch=23/25, avg_epoch_loss=6.96]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.46it/s, epoch=24/25, avg_epoch_loss=6.96]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.59it/s, epoch=25/25, avg_epoch_loss=6.95]
# Running evaluation: 100%|███████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 100.22it/s]
# WARNING:root: Running Unit: Buffalo Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.88it/s, epoch=1/25, avg_epoch_loss=8.12]
# 100%|██████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.35it/s, epoch=2/25, avg_epoch_loss=7.5]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.35it/s, epoch=3/25, avg_epoch_loss=7.39]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.29it/s, epoch=4/25, avg_epoch_loss=7.34]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.26it/s, epoch=5/25, avg_epoch_loss=7.33]
# 100%|██████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.30it/s, epoch=6/25, avg_epoch_loss=7.3]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.30it/s, epoch=7/25, avg_epoch_loss=7.28]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.39it/s, epoch=8/25, avg_epoch_loss=7.28]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.37it/s, epoch=9/25, avg_epoch_loss=7.21]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.34it/s, epoch=10/25, avg_epoch_loss=7.24]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.28it/s, epoch=11/25, avg_epoch_loss=7.24]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.24it/s, epoch=12/25, avg_epoch_loss=7.24]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.25it/s, epoch=13/25, avg_epoch_loss=7.21]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.39it/s, epoch=14/25, avg_epoch_loss=7.22]
# 100%|████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.96it/s, epoch=15/25, avg_epoch_loss=7.21]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.22it/s, epoch=16/25, avg_epoch_loss=7.19]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.34it/s, epoch=17/25, avg_epoch_loss=7.18]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.30it/s, epoch=18/25, avg_epoch_loss=7.18]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.33it/s, epoch=19/25, avg_epoch_loss=7.17]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.29it/s, epoch=20/25, avg_epoch_loss=7.17]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.29it/s, epoch=21/25, avg_epoch_loss=7.17]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.33it/s, epoch=22/25, avg_epoch_loss=7.12]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.38it/s, epoch=23/25, avg_epoch_loss=7.15]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.32it/s, epoch=24/25, avg_epoch_loss=7.15]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.28it/s, epoch=25/25, avg_epoch_loss=7.12]
# Running evaluation: 100%|█████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 131.60it/s]
# WARNING:root: Running Unit: Central Buffalo Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.08it/s, epoch=1/25, avg_epoch_loss=8.69]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.69it/s, epoch=2/25, avg_epoch_loss=8.39]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.53it/s, epoch=3/25, avg_epoch_loss=8.18]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.39it/s, epoch=4/25, avg_epoch_loss=7.99]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.39it/s, epoch=5/25, avg_epoch_loss=7.87]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.41it/s, epoch=6/25, avg_epoch_loss=7.78]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.46it/s, epoch=7/25, avg_epoch_loss=7.75]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.55it/s, epoch=8/25, avg_epoch_loss=7.67]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.61it/s, epoch=9/25, avg_epoch_loss=7.63]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.68it/s, epoch=10/25, avg_epoch_loss=7.62]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.64it/s, epoch=11/25, avg_epoch_loss=7.59]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.67it/s, epoch=12/25, avg_epoch_loss=7.6]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.58it/s, epoch=13/25, avg_epoch_loss=7.49]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.69it/s, epoch=14/25, avg_epoch_loss=7.5]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.74it/s, epoch=15/25, avg_epoch_loss=7.45]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.73it/s, epoch=16/25, avg_epoch_loss=7.49]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.39it/s, epoch=17/25, avg_epoch_loss=7.41]
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.37it/s, epoch=18/25, avg_epoch_loss=7.4]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.49it/s, epoch=19/25, avg_epoch_loss=7.42]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.69it/s, epoch=20/25, avg_epoch_loss=7.38]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.52it/s, epoch=21/25, avg_epoch_loss=7.37]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.69it/s, epoch=22/25, avg_epoch_loss=7.32]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.71it/s, epoch=23/25, avg_epoch_loss=7.36]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.74it/s, epoch=24/25, avg_epoch_loss=7.31]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.71it/s, epoch=25/25, avg_epoch_loss=7.29]
# Running evaluation: 100%|█████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 118.44it/s]
# WARNING:root: Running Unit: East Harding Springs Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.18it/s, epoch=1/25, avg_epoch_loss=8.63]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.81it/s, epoch=2/25, avg_epoch_loss=8.21]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.83it/s, epoch=3/25, avg_epoch_loss=7.86]
# 100%|██████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.65it/s, epoch=4/25, avg_epoch_loss=7.7]
# 100%|██████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.80it/s, epoch=5/25, avg_epoch_loss=7.5]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.76it/s, epoch=6/25, avg_epoch_loss=7.46]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.72it/s, epoch=7/25, avg_epoch_loss=7.38]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.70it/s, epoch=8/25, avg_epoch_loss=7.21]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.76it/s, epoch=9/25, avg_epoch_loss=7.18]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.78it/s, epoch=10/25, avg_epoch_loss=7.15]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.83it/s, epoch=11/25, avg_epoch_loss=7.12]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.61it/s, epoch=12/25, avg_epoch_loss=7.06]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.64it/s, epoch=13/25, avg_epoch_loss=6.99]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.67it/s, epoch=14/25, avg_epoch_loss=7.01]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.66it/s, epoch=15/25, avg_epoch_loss=6.97]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.58it/s, epoch=16/25, avg_epoch_loss=6.96]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.87it/s, epoch=17/25, avg_epoch_loss=6.92]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.85it/s, epoch=18/25, avg_epoch_loss=6.91]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.81it/s, epoch=19/25, avg_epoch_loss=6.85]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.80it/s, epoch=20/25, avg_epoch_loss=6.85]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.81it/s, epoch=21/25, avg_epoch_loss=6.82]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.84it/s, epoch=22/25, avg_epoch_loss=7.13]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.78it/s, epoch=23/25, avg_epoch_loss=7.2]
# 100%|████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.89it/s, epoch=24/25, avg_epoch_loss=6.84]
# 100%|████████████████████████████████████████████████| 50/50 [00:09<00:00,  5.49it/s, epoch=25/25, avg_epoch_loss=6.75]
# Running evaluation: 100%|███████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 125.00it/s]
# WARNING:root: Running Unit: North Buffalo Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.96it/s, epoch=1/25, avg_epoch_loss=9.49]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.66it/s, epoch=2/25, avg_epoch_loss=8.22]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.78it/s, epoch=3/25, avg_epoch_loss=8.08]
# 100%|████████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.71it/s, epoch=4/25, avg_epoch_loss=8]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.81it/s, epoch=5/25, avg_epoch_loss=7.96]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.75it/s, epoch=6/25, avg_epoch_loss=7.91]
# 100%|█████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.92it/s, epoch=7/25, avg_epoch_loss=7.93]
# 100%|█████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.25it/s, epoch=8/25, avg_epoch_loss=7.84]
# 100%|██████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.63it/s, epoch=9/25, avg_epoch_loss=7.8]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.76it/s, epoch=10/25, avg_epoch_loss=7.74]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.58it/s, epoch=11/25, avg_epoch_loss=7.67]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.96it/s, epoch=12/25, avg_epoch_loss=7.59]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.30it/s, epoch=13/25, avg_epoch_loss=7.53]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.59it/s, epoch=14/25, avg_epoch_loss=7.43]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.45it/s, epoch=15/25, avg_epoch_loss=7.41]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.24it/s, epoch=16/25, avg_epoch_loss=7.34]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.32it/s, epoch=17/25, avg_epoch_loss=7.33]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.38it/s, epoch=18/25, avg_epoch_loss=7.61]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.43it/s, epoch=19/25, avg_epoch_loss=7.38]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.44it/s, epoch=20/25, avg_epoch_loss=7.29]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.73it/s, epoch=21/25, avg_epoch_loss=7.22]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.38it/s, epoch=22/25, avg_epoch_loss=7.2]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.91it/s, epoch=23/25, avg_epoch_loss=7.13]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.91it/s, epoch=24/25, avg_epoch_loss=7.11]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.15it/s, epoch=25/25, avg_epoch_loss=7.07]
# Running evaluation: 100%|███████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 289.50it/s]
# WARNING:root: Running Unit: Pete's Creek Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.50it/s, epoch=1/25, avg_epoch_loss=8.13]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.56it/s, epoch=2/25, avg_epoch_loss=7.78]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.89it/s, epoch=3/25, avg_epoch_loss=7.74]
# 100%|██████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.02it/s, epoch=4/25, avg_epoch_loss=7.7]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.94it/s, epoch=5/25, avg_epoch_loss=7.63]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.09it/s, epoch=6/25, avg_epoch_loss=7.54]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.07it/s, epoch=7/25, avg_epoch_loss=7.49]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.08it/s, epoch=8/25, avg_epoch_loss=7.45]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.90it/s, epoch=9/25, avg_epoch_loss=7.44]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.79it/s, epoch=10/25, avg_epoch_loss=7.4]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.95it/s, epoch=11/25, avg_epoch_loss=7.37]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.90it/s, epoch=12/25, avg_epoch_loss=7.39]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.84it/s, epoch=13/25, avg_epoch_loss=7.34]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.95it/s, epoch=14/25, avg_epoch_loss=7.33]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.79it/s, epoch=15/25, avg_epoch_loss=7.29]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.90it/s, epoch=16/25, avg_epoch_loss=7.32]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.97it/s, epoch=17/25, avg_epoch_loss=7.28]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.85it/s, epoch=18/25, avg_epoch_loss=7.27]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.04it/s, epoch=19/25, avg_epoch_loss=7.23]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.00it/s, epoch=20/25, avg_epoch_loss=7.11]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.03it/s, epoch=21/25, avg_epoch_loss=7.13]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.08it/s, epoch=22/25, avg_epoch_loss=7.03]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.90it/s, epoch=23/25, avg_epoch_loss=6.94]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.97it/s, epoch=24/25, avg_epoch_loss=6.91]
# 100%|███████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.98it/s, epoch=25/25, avg_epoch_loss=7]
# Running evaluation: 100%|███████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 274.95it/s]
# WARNING:root: Running Unit: South Buffalo Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.48it/s, epoch=1/25, avg_epoch_loss=8.03]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.39it/s, epoch=2/25, avg_epoch_loss=7.59]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.64it/s, epoch=3/25, avg_epoch_loss=7.51]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.82it/s, epoch=4/25, avg_epoch_loss=7.42]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.82it/s, epoch=5/25, avg_epoch_loss=7.34]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.88it/s, epoch=6/25, avg_epoch_loss=7.31]
# 100%|██████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.69it/s, epoch=7/25, avg_epoch_loss=7.3]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.92it/s, epoch=8/25, avg_epoch_loss=7.24]
# 100%|██████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.14it/s, epoch=9/25, avg_epoch_loss=7.2]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.02it/s, epoch=10/25, avg_epoch_loss=7.19]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.06it/s, epoch=11/25, avg_epoch_loss=7.16]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.45it/s, epoch=12/25, avg_epoch_loss=7.19]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.31it/s, epoch=13/25, avg_epoch_loss=7.15]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.99it/s, epoch=14/25, avg_epoch_loss=7.17]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.10it/s, epoch=15/25, avg_epoch_loss=7.12]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.25it/s, epoch=16/25, avg_epoch_loss=7.11]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.59it/s, epoch=17/25, avg_epoch_loss=7.1]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.70it/s, epoch=18/25, avg_epoch_loss=7.06]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.93it/s, epoch=19/25, avg_epoch_loss=7.07]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.33it/s, epoch=20/25, avg_epoch_loss=7.12]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.29it/s, epoch=21/25, avg_epoch_loss=7.11]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.70it/s, epoch=22/25, avg_epoch_loss=7.09]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.48it/s, epoch=23/25, avg_epoch_loss=7.05]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.10it/s, epoch=24/25, avg_epoch_loss=7.06]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.80it/s, epoch=25/25, avg_epoch_loss=7.04]
# Running evaluation: 100%|█████████████████████████████████████████████████████████████| 75/75 [00:00<00:00, 337.66it/s]
# WARNING:root: Running Unit: West Buffalo B Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.61it/s, epoch=1/25, avg_epoch_loss=7.71]
# 100%|██████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.79it/s, epoch=2/25, avg_epoch_loss=6.7]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.67it/s, epoch=3/25, avg_epoch_loss=6.57]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.90it/s, epoch=4/25, avg_epoch_loss=6.49]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.54it/s, epoch=5/25, avg_epoch_loss=6.48]
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.78it/s, epoch=6/25, avg_epoch_loss=6.44]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.73it/s, epoch=7/25, avg_epoch_loss=6.39]
# 100%|██████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.74it/s, epoch=8/25, avg_epoch_loss=6.4]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.95it/s, epoch=9/25, avg_epoch_loss=6.36]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.78it/s, epoch=10/25, avg_epoch_loss=6.34]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.73it/s, epoch=11/25, avg_epoch_loss=6.3]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.79it/s, epoch=12/25, avg_epoch_loss=6.31]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.77it/s, epoch=13/25, avg_epoch_loss=6.3]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.46it/s, epoch=14/25, avg_epoch_loss=6.27]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.19it/s, epoch=15/25, avg_epoch_loss=6.28]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.96it/s, epoch=16/25, avg_epoch_loss=6.28]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.59it/s, epoch=17/25, avg_epoch_loss=6.23]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.05it/s, epoch=18/25, avg_epoch_loss=6.24]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.44it/s, epoch=19/25, avg_epoch_loss=6.21]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.57it/s, epoch=20/25, avg_epoch_loss=6.24]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.37it/s, epoch=21/25, avg_epoch_loss=6.22]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.51it/s, epoch=22/25, avg_epoch_loss=6.2]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.12it/s, epoch=23/25, avg_epoch_loss=6.23]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.16it/s, epoch=24/25, avg_epoch_loss=6.18]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.31it/s, epoch=25/25, avg_epoch_loss=6.16]
# Running evaluation: 100%|█████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 272.40it/s]
# WARNING:root: Running Unit: West Buffalo Red River Unit
# 100%|█████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.27it/s, epoch=1/25, avg_epoch_loss=7.87]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.08it/s, epoch=2/25, avg_epoch_loss=7.28]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.09it/s, epoch=3/25, avg_epoch_loss=7.12]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.95it/s, epoch=4/25, avg_epoch_loss=7.09]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.97it/s, epoch=5/25, avg_epoch_loss=7.01]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.07it/s, epoch=6/25, avg_epoch_loss=6.92]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.21it/s, epoch=7/25, avg_epoch_loss=6.93]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.33it/s, epoch=8/25, avg_epoch_loss=6.91]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.22it/s, epoch=9/25, avg_epoch_loss=6.87]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.37it/s, epoch=10/25, avg_epoch_loss=6.87]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.44it/s, epoch=11/25, avg_epoch_loss=6.85]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.38it/s, epoch=12/25, avg_epoch_loss=6.79]
# 100%|█████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.44it/s, epoch=13/25, avg_epoch_loss=6.8]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.37it/s, epoch=14/25, avg_epoch_loss=6.76]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.86it/s, epoch=15/25, avg_epoch_loss=6.75]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.76it/s, epoch=16/25, avg_epoch_loss=6.75]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.50it/s, epoch=17/25, avg_epoch_loss=6.77]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.45it/s, epoch=18/25, avg_epoch_loss=6.77]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.61it/s, epoch=19/25, avg_epoch_loss=6.71]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.26it/s, epoch=20/25, avg_epoch_loss=6.69]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.06it/s, epoch=21/25, avg_epoch_loss=6.73]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.15it/s, epoch=22/25, avg_epoch_loss=6.65]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.95it/s, epoch=23/25, avg_epoch_loss=6.69]
# 100%|████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.20it/s, epoch=24/25, avg_epoch_loss=6.65]
# 100%|████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.16it/s, epoch=25/25, avg_epoch_loss=6.63]
# Running evaluation: 100%|█████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 283.06it/s]

# %%
results_list = []
for x in results:
    results_list.append({"Unit Name":x["Unit_Name"], "Inj Data Volume":x['Inj_Data_Vol'],
                         "Prod Data Volume":x['Prod_Data_Vol'], "MAPE":x['agg_metrics']['MAPE'],
                          "mCRPS":x['agg_metrics']['Mean CRPS']})
results_DF = pd.DataFrame(results_list)

# %%
results_DF
# Out:
#                              Unit Name  Inj Data Volume  Prod Data Volume  \
# 0                      Alum Creek Unit              150               160
# 1               Buffalo Red River Unit              318               560
# 2       Central Buffalo Red River Unit               61               168
# 3  East Harding Springs Red River Unit               53               106
# 4         North Buffalo Red River Unit               71               107
# 5          Pete's Creek Red River Unit               83               119
# 6         South Buffalo Red River Unit              575              1226
# 7        West Buffalo B Red River Unit              271               210
# 8          West Buffalo Red River Unit              208               479
#
#        MAPE        mCRPS
# 0  1.126610   109.361242
# 1  3.750906   225.705074
# 2  0.962789   972.504547
# 3  1.514820  1047.547929
# 4  1.020093   398.593592
# 5  1.325236   849.311540
# 6  1.429650   191.094352
# 7  6.270552   168.314361
# 8  1.079872   194.787391

# %%
#results_Copy = results_DF
#results_DF_Copy = results_DF
results_DF_Copy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22600/4036348012.py in <module>
#       1 #results_Copy = results_DF
#       2 #results_DF_Copy = results_DF
# ----> 3 results_DF_Copy
#
# NameError: name 'results_DF_Copy' is not defined

# %%
well_names = []
well_groups = prodDF.groupby(prodDF.Well_Name)
for well, data in well_groups:
    well_names.append(well)

# %%
plt.scatter(x=results_DF.Prod_Data_Vol + results_DF.Inj_Data_Vol, y=results_DF.MAPE)

# %%
def plot_prob_forecasts(ts_entry, forecast_entry, well_name):
    plot_length = 200
    prediction_intervals = (50.0, 90.0)
    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]

    fig, ax = plt.subplots(1, 1, figsize=(10, 7))
    ts_entry[-plot_length:].plot(ax=ax)  # plot the time series
    forecast_entry.plot(prediction_intervals=prediction_intervals, color='g')
    plt.subplots_adjust(left=0.0, bottom=0.0, right=1.15, top=1.0, wspace=0.2, hspace=0.2)
    plt.grid(which="both")
    plt.legend(legend, loc="upper right")
    plt.xlabel('year')
    plt.ylabel('Oil bbls')
    plt.title("+Injection " + well_name + " Forecast")
    plt.show()

# %%
for i in range(len(results[1]['tss'])):
    #if well_names[i] == "I-28H McKitrick": #in test_wells:
    plot_prob_forecasts(results[1]['tss'][i], results[1]['forecasts'][i], well_names[i])

# %%
aggDict = {'MAPE':round(agg_metrics['MAPE'], 3), 
           'Mean CRPS':round(agg_metrics['Mean CRPS'], 4)}
aggDF = pd.DataFrame([aggDict])
aggDF
# Out:
#     MAPE  Mean CRPS
# 0  1.212   165.7567

# %%
#1.087	111.9364

# %%
top_metrics = []
for i in range(len(item_metrics)):
    item_metrics.item_id[i] = well_names[i]
    if well_names[i] in test_wells:
        top_metrics.append(item_metrics.iloc[i])
top_metrics_DF = pd.DataFrame(top_metrics)
top_metrics_DF.drop(columns=['MSE', 'abs_target_sum', 'MSIS', 'QuantileLoss[0.1]',
                            'QuantileLoss[0.5]', 'QuantileLoss[0.9]', 'seasonal_error', 'MASE', 'sMAPE', 'abs_error',
                            'Coverage[0.1]', 'Coverage[0.5]', 'Coverage[0.9]'])
top_metrics_DF = top_metrics_DF.rename(columns={"item_id": "Well Name", "abs_target_mean": "Mean Oil bbls"})
top_metrics_DF = top_metrics_DF[['Well Name', 'Mean Oil bbls', 'RMSE', 'Mean CRPS', 'MAPE']]
top_metrics_DF
# Out:
#       Well Name  Mean Oil bbls        RMSE   Mean CRPS      MAPE
# 57  SBRRU 14-28     428.233333  269.027647  156.256348  6.518790
# 74  SBRRU 34-11     774.333333  281.243163  161.389297  0.331082
